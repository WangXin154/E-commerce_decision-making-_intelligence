# %%
import pandas as pd
from numpy.ma.extras import column_stack

df_orders = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_order_items_dataset.csv")
print(df_orders["shipping_limit_date"].head())
# Out:
# 0    2017-09-19 09:45:35
# 1    2017-05-03 11:05:13
# 2    2018-01-18 14:48:30
# 3    2018-08-15 10:10:18
# 4    2017-02-13 13:57:51
# Name: shipping_limit_date, dtype: str

# %%
# input data
df = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_orders_dataset.csv")
print(df.columns.tolist)
print(df.dtypes)
print(df.head(2))
print(len(df))
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='str')>
# order_id                         str
# customer_id                      str
# order_status                     str
# order_purchase_timestamp         str
# order_approved_at                str
# order_delivered_carrier_date     str
# order_delivered_customer_date    str
# order_estimated_delivery_date    str
# dtype: object
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# ...

# %%
import pandas as pd
from numpy.ma.extras import column_stack
df = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_order_items_dataset.csv")
print(df.columns.tolist)
print(df.dtypes)
print(df.head(2))
print(len(df))
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'order_item_id', 'product_id', 'seller_id',
#        'shipping_limit_date', 'price', 'freight_value'],
#       dtype='str')>
# order_id                   str
# order_item_id            int64
# product_id                 str
# seller_id                  str
# shipping_limit_date        str
# price                  float64
# freight_value          float64
# dtype: object
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
#
#    shipping_limit_date  price  freight_value
# 0  2017-09-19 09:45:35   58.9          13.29
# 1  2017-05-03 11:05:13  239.9          19.93
# 112650

# %%
import pandas as pd
from numpy.ma.extras import column_stack
df = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_products_dataset.csv")
print(df.columns.tolist)
print(df.dtypes)
print(df.head(2))
print(len(df))
# Out:
# <bound method IndexOpsMixin.tolist of Index(['product_id', 'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm'],
#       dtype='str')>
# product_id                        str
# product_category_name             str
# product_name_lenght           float64
# product_description_lenght    float64
# product_photos_qty            float64
# product_weight_g              float64
# product_length_cm             float64
# product_height_cm             float64
# product_width_cm              float64
# dtype: object
#                          product_id product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5            perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                 artes
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# ...

# %%
import pandas as pd
from numpy.ma.extras import column_stack
df = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_customers_dataset.csv")
print(df.columns.tolist)
print(df.dtypes)
print(df.head(2))
print(len(df))
# Out:
# <bound method IndexOpsMixin.tolist of Index(['customer_id', 'customer_unique_id', 'customer_zip_code_prefix',
#        'customer_city', 'customer_state'],
#       dtype='str')>
# customer_id                   str
# customer_unique_id            str
# customer_zip_code_prefix    int64
# customer_city                 str
# customer_state                str
# dtype: object
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 99441

# %%
import pandas as pd
from numpy.ma.extras import column_stack
df = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_order_payments_dataset.csv")
print(df.columns.tolist)
print(df.dtypes)
print(df.head(2))
print(len(df))
# Out:
# <bound method IndexOpsMixin.tolist of Index(['order_id', 'payment_sequential', 'payment_type',
#        'payment_installments', 'payment_value'],
#       dtype='str')>
# order_id                    str
# payment_sequential        int64
# payment_type                str
# payment_installments      int64
# payment_value           float64
# dtype: object
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 103886

# %%
import pandas as pd
from numpy.ma.extras import column_stack
df = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_order_reviews_dataset.csv")
print(df.columns.tolist)
print(df.dtypes)
print(df.head(2))
print(len(df))
# Out:
# <bound method IndexOpsMixin.tolist of Index(['review_id', 'order_id', 'review_score', 'review_comment_title',
#        'review_comment_message', 'review_creation_date',
#        'review_answer_timestamp'],
#       dtype='str')>
# review_id                    str
# order_id                     str
# review_score               int64
# review_comment_title         str
# review_comment_message       str
# review_creation_date         str
# review_answer_timestamp      str
# dtype: object
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
#
#    review_score review_comment_title review_comment_message  \
# 0             4                  NaN                    NaN
# 1             5                  NaN                    NaN
#
#   review_creation_date review_answer_timestamp
# ...

# %%
import pandas as pd
from numpy.ma.extras import column_stack
df = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_sellers_dataset.csv")
print(df.columns.tolist)
print(df.dtypes)
print(df.head(2))
print(len(df))
# Out:
# <bound method IndexOpsMixin.tolist of Index(['seller_id', 'seller_zip_code_prefix', 'seller_city', 'seller_state'], dtype='str')>
# seller_id                   str
# seller_zip_code_prefix    int64
# seller_city                 str
# seller_state                str
# dtype: object
#                           seller_id  seller_zip_code_prefix seller_city  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023    campinas
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844  mogi guacu
#
#   seller_state
# 0           SP
# 1           SP
# 3095

# %%
# test
row = df.iloc[0]

print(type(row))
print(row)
print(row["order_id"])
print(row["order_purchase_timestamp"])
# Out:
# <class 'pandas.Series'>
# order_id                         e481f51cbdc54678b7cc49136f2d6af7
# customer_id                      9ef432eb6251297304e76186b10a928d
# order_status                                            delivered
# order_purchase_timestamp                      2017-10-02 10:56:33
# order_approved_at                             2017-10-02 11:07:15
# order_delivered_carrier_date                  2017-10-04 19:55:00
# order_delivered_customer_date                 2017-10-10 21:25:13
# order_estimated_delivery_date                 2017-10-18 00:00:00
# Name: 0, dtype: str
# e481f51cbdc54678b7cc49136f2d6af7
# 2017-10-02 10:56:33

# %%
from src.utils.db import get_connection, execute_sql, close_connection, execute_many

conn = get_connection()
print("Is the connection open:", conn.open)

sql = "SELECT 1"
result = execute_sql(conn, sql)
print("Number of rows affected", result)

close_connection(conn)
# Out:
# Is the connection open: True
# Number of rows affected 1

# %%
# import pandas as pd
# df_1 = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_orders_dataset.csv")
#
# row = df_1.iloc[0]
#
# def safe_value(v):
#     if pd.isna(v):
#         return None
#     return v
# params = (
#     safe_value(row["order_id"]),
#     safe_value(row["customer_id"]),
#     safe_value(row["order_status"]),
#     safe_value(row["order_purchase_timestamp"]),
#     safe_value(row["order_approved_at"]),
#     safe_value(row["order_delivered_carrier_date"]),
#     safe_value(row["order_delivered_customer_date"]),
#     safe_value(row["order_estimated_delivery_date"]),
# )
#
# sql = """
# INSERT INTO orders_raw (
#   order_id,
#   customer_id,
#   order_status,
#   order_purchase_timestamp,
#   order_approved_at,
#   order_delivered_carrier_date,
#   order_delivered_customer_date,
#   order_estimated_delivery_date
# ) VALUES (%s,%s,%s,%s,%s,%s,%s,%s)
# """
# # print(safe_value(row["order_id"]))
# # print(safe_value(float("nan")))
#
# conn = get_connection()
# execute_sql(conn, sql, params)
# close_connection(conn)

# %%
# Import multi-line tests
df_1 = pd.read_csv(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_orders_dataset.csv")

batch = []

for i in range(5):
    row = df_1.iloc[i]
    params = (
        row["order_id"],
        row["customer_id"],
        row["order_status"],
        row["order_purchase_timestamp"],
        row["order_approved_at"],
        row["order_delivered_carrier_date"],
        row["order_delivered_customer_date"],
        row["order_estimated_delivery_date"],
    )
    batch.append(params)
print(batch)
# Out:
# [('e481f51cbdc54678b7cc49136f2d6af7', '9ef432eb6251297304e76186b10a928d', 'delivered', '2017-10-02 10:56:33', '2017-10-02 11:07:15', '2017-10-04 19:55:00', '2017-10-10 21:25:13', '2017-10-18 00:00:00'), ('53cdb2fc8bc7dce0b6741e2150273451', 'b0830fb4747a6c6d20dea0b8c802d7ef', 'delivered', '2018-07-24 20:41:37', '2018-07-26 03:24:27', '2018-07-26 14:31:00', '2018-08-07 15:27:45', '2018-08-13 00:00:00'), ('47770eb9100c2d0c44946d9cf07ec65d', '41ce2a54c0b03bf3443c3d931a367089', 'delivered', '2018-08-08 08:38:49', '2018-08-08 08:55:23', '2018-08-08 13:50:00', '2018-08-17 18:06:29', '2018-09-04 00:00:00'), ('949d5b44dbf5de918fe9c16f97b45f8a', 'f88197465ea7920adcdbec7375364d82', 'delivered', '2017-11-18 19:28:06', '2017-11-18 19:45:59', '2017-11-22 13:39:59', '2017-12-02 00:28:42', '2017-12-15 00:00:00'), ('ad21c59c0840e6cb83a9ceb5573f8159', '8ab97904e6daea8866dbdbc4fb7aad2c', 'delivered', '2018-02-13 21:18:39', '2018-02-13 22:20:29', '2018-02-14 19:46:34', '2018-02-16 18:17:02', '2018-02-26
# ...

# %%
# !!!Import orders_dataset data into sql
from src.etl.load_orders import load_orders_raw

load_orders_raw(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_orders_dataset.csv")
# Out:
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# ...

# %%
# !!!Import orders_dataset data into sql
from src.etl.load_orders import load_orders_raw

load_orders_raw(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_orders_dataset.csv")

# %%
# !! Import order_items_dataset data into sql
from src.etl.load_order_items import load_order_items_raw

load_order_items_raw(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_order_items_dataset.csv")
# Out:
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# ...

# %%
# !! Import products_dataset data into sql
from src.etl.load_products import load_products_raw

load_products_raw(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_products_dataset.csv")
# Out:
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 951 rows

# %%
# !! Import customers_dataset data into sql
from src.etl.load_customers import load_customers_raw

load_customers_raw(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_customers_dataset.csv")
# Out:
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# ...

# %%
# !! Import payments_dataset data into sql
from src.etl.load_payments import load_payments_raw

load_payments_raw(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_order_payments_dataset.csv")
# Out:
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# ...

# %%
# !! Import reviews_dataset data into sql
from src.etl.load_reviews import load_reviews_raw

load_reviews_raw(r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_order_reviews_dataset.csv")
# Out:
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# ...

# %%
# !! Import sellers_dataset data into sql
from src.etl.load_sellers import load_sellers_raw

load_sellers_raw(
    r"C:\Users\wangxinxin\Documents\GitHub\E-commerce_decision-making _ntelligence\data\olist_sellers_dataset.csv")
# Out:
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 1000 rows
# Inserted 95 rows
